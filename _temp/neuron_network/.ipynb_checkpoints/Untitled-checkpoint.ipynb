# %%
import pandas as pd
import string

# %%
df_test = pd.read_csv("SK하이닉스.csv")

# %%
df_test_p1 = df_test['pattern1']
df_test_p1
# Out:
# 0       P05
# 1       M05
# 2       K00
# 3       K00
# 4       M05
#        ...
# 2161    P05
# 2162    M05
# 2163    P05
# 2164    M05
# 2165    M05
# Name: pattern1, Length: 2166, dtype: object

# %%
temp = list(df_test_p1)
temp = [list(string) for string in temp]
temp
# Out:
# [['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '2'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['P', '0', '1'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '1'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['K', '0', '0'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '4'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '2'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '2'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['M', '0', '4'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '1'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '0'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '0'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['P', '0', '4'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '4'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '0'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '3'],
#  ['K', '0', '0'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '2'],
#  ['M', '0', '1'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '1'],
#  ['K', '0', '2'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '1'],
#  ['K', '0', '1'],
#  ['P', '0', '3'],
#  ['M', '0', '3'],
#  ['M', '0', '2'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '0'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['P', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '3'],
#  ['P', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['K', '0', '2'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '2'],
#  ['K', '0', '0'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '1'],
#  ['K', '0', '2'],
#  ['M', '0', '1'],
#  ['K', '0', '1'],
#  ['M', '0', '2'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '1'],
#  ['M', '0', '1'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '1'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '3'],
#  ['K', '0', '2'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '4'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '2'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['K', '0', '1'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '4'],
#  ['P', '0', '3'],
#  ['P', '0', '3'],
#  ['K', '0', '0'],
#  ['K', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '3'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['K', '0', '0'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['P', '0', '5'],
#  ['K', '0', '1'],
#  ['M', '0', '4'],
#  ['P', '0', '5'],
#  ['P', '0', '1'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '0'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '1'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '2'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['P', '0', '3'],
#  ['M', '0', '4'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['P', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '3'],
#  ['M', '0', '1'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '5'],
#  ['P', '0', '5'],
#  ['K', '0', '0'],
#  ['P', '0', '3'],
#  ['K', '0', '0'],
#  ['P', '0', '1'],
#  ['P', '0', '5'],
#  ['M', '0', '3'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '3'],
#  ['K', '0', '0'],
#  ['K', '0', '0'],
#  ['M', '0', '3'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['M', '0', '5'],
#  ['K', '0', '2'],
#  ['P', '0', '1'],
#  ['M', '0', '3'],
#  ['P', '0', '5'],
#  ['P', '0', '0'],
#  ...]

# %%
# Out:
# ['P05',
#  'M05',
#  'K00',
#  'K00',
#  'M05',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'P01',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'P05',
#  'M01',
#  'M05',
#  'P05',
#  'P05',
#  'P01',
#  'M02',
#  'M05',
#  'M01',
#  'M05',
#  'P05',
#  'P05',
#  'K00',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'K02',
#  'P01',
#  'K00',
#  'P05',
#  'M05',
#  'K00',
#  'M05',
#  'K01',
#  'M01',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M03',
#  'M05',
#  'M05',
#  'P00',
#  'M05',
#  'M05',
#  'P03',
#  'P05',
#  'K00',
#  'K00',
#  'P05',
#  'K00',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'P05',
#  'M03',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M03',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'K00',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P03',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M01',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'K01',
#  'M03',
#  'M05',
#  'M05',
#  'K02',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'P03',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'P03',
#  'P05',
#  'M03',
#  'P00',
#  'M05',
#  'M05',
#  'K00',
#  'K00',
#  'M05',
#  'M05',
#  'M03',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P03',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'P05',
#  'K01',
#  'K01',
#  'M05',
#  'P05',
#  'M05',
#  'K00',
#  'P05',
#  'P03',
#  'M05',
#  'M05',
#  'M05',
#  'K02',
#  'M05',
#  'K00',
#  'M05',
#  'P03',
#  'P05',
#  'P05',
#  'M03',
#  'M01',
#  'P05',
#  'M05',
#  'M01',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P05',
#  'M03',
#  'M03',
#  'K00',
#  'M05',
#  'M05',
#  'P03',
#  'K00',
#  'K01',
#  'M05',
#  'P05',
#  'M03',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'K00',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'K01',
#  'P05',
#  'M05',
#  'K00',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'K00',
#  'M05',
#  'M03',
#  'P05',
#  'P05',
#  'K02',
#  'M05',
#  'M05',
#  'M05',
#  'M03',
#  'K00',
#  'P05',
#  'P05',
#  'K00',
#  'P05',
#  'P05',
#  'M05',
#  'M03',
#  'K00',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P03',
#  'P05',
#  'K00',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P01',
#  'K01',
#  'M05',
#  'M05',
#  'K02',
#  'M01',
#  'M05',
#  'K01',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'K00',
#  'M05',
#  'M03',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'K00',
#  'P05',
#  'P05',
#  'M05',
#  'P05',
#  'K00',
#  'P05',
#  'P05',
#  'K00',
#  'M05',
#  'P05',
#  'M03',
#  'M03',
#  'M05',
#  'P03',
#  'P05',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'K00',
#  'P05',
#  'M05',
#  'M04',
#  'M05',
#  'K00',
#  'M03',
#  'P05',
#  'K00',
#  'P01',
#  'M05',
#  'M01',
#  'M03',
#  'M05',
#  'M05',
#  'P05',
#  'P01',
#  'M01',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'M02',
#  'M05',
#  'M05',
#  'K00',
#  'K02',
#  'K01',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'M01',
#  'P03',
#  'M05',
#  'K00',
#  'P03',
#  'P05',
#  'P05',
#  'P05',
#  'M03',
#  'P05',
#  'K02',
#  'M05',
#  'M04',
#  'K00',
#  'P05',
#  'K00',
#  'K01',
#  'M05',
#  'K00',
#  'M03',
#  'M05',
#  'P05',
#  'M05',
#  'K02',
#  'M05',
#  'M05',
#  'M05',
#  'P00',
#  'M05',
#  'M05',
#  'P05',
#  'M03',
#  'K00',
#  'K01',
#  'M05',
#  'P01',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P01',
#  'K00',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M03',
#  'M05',
#  'P05',
#  'P03',
#  'M05',
#  'M01',
#  'M01',
#  'K00',
#  'K00',
#  'P05',
#  'M05',
#  'K01',
#  'M05',
#  'M03',
#  'M05',
#  'P03',
#  'P05',
#  'P00',
#  'P05',
#  'K00',
#  'K00',
#  'K02',
#  'M05',
#  'P05',
#  'K00',
#  'M05',
#  'M05',
#  'P03',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'P05',
#  'P01',
#  'M05',
#  'P01',
#  'P01',
#  'M05',
#  'M05',
#  'K00',
#  'P03',
#  'P05',
#  'M05',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P01',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'K00',
#  'K00',
#  'M05',
#  'K01',
#  'P05',
#  'M05',
#  'M00',
#  'M03',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'P03',
#  'M00',
#  'P05',
#  'M05',
#  'M05',
#  'K00',
#  'M03',
#  'P04',
#  'M05',
#  'K00',
#  'M05',
#  'M05',
#  'P03',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P01',
#  'P05',
#  'P01',
#  'M05',
#  'K00',
#  'M05',
#  'M05',
#  'M05',
#  'P03',
#  'P05',
#  'M05',
#  'P05',
#  'K01',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'K00',
#  'P01',
#  'M05',
#  'M05',
#  'P05',
#  'K00',
#  'M03',
#  'P05',
#  'P05',
#  'P05',
#  'P05',
#  'M05',
#  'K01',
#  'M04',
#  'P01',
#  'M05',
#  'M05',
#  'M03',
#  'P00',
#  'M03',
#  'P05',
#  'M03',
#  'P03',
#  'K00',
#  'P01',
#  'P05',
#  'P05',
#  'M03',
#  'M05',
#  'P01',
#  'K00',
#  'M03',
#  'M05',
#  'P01',
#  'K00',
#  'M05',
#  'M05',
#  'K00',
#  'P05',
#  'M05',
#  'K00',
#  'M05',
#  'M05',
#  'P05',
#  'M02',
#  'M01',
#  'P01',
#  'P05',
#  'M01',
#  'M01',
#  'M05',
#  'M05',
#  'K02',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M03',
#  'K00',
#  'K00',
#  'P03',
#  'M05',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'P01',
#  'P01',
#  'K02',
#  'P05',
#  'K00',
#  'M05',
#  'M03',
#  'M05',
#  'M05',
#  'K00',
#  'M05',
#  'K01',
#  'M05',
#  'P05',
#  'K01',
#  'M05',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'K00',
#  'M01',
#  'K01',
#  'P03',
#  'M03',
#  'M02',
#  'K01',
#  'P05',
#  'M05',
#  'P00',
#  'M05',
#  'K00',
#  'K00',
#  'M05',
#  'M05',
#  'M01',
#  'M05',
#  'P00',
#  'P05',
#  'P05',
#  'P01',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'K01',
#  'P05',
#  'P05',
#  'M05',
#  'P01',
#  'M01',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'M03',
#  'P05',
#  'M01',
#  'P05',
#  'K01',
#  'M01',
#  'P05',
#  'P05',
#  'M01',
#  'M03',
#  'K00',
#  'K02',
#  'M05',
#  'P01',
#  'M05',
#  'P05',
#  'M05',
#  'P01',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'M03',
#  'P00',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'M01',
#  'M03',
#  'P01',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'K01',
#  'P05',
#  'M03',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M00',
#  'P05',
#  'M03',
#  'P03',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'M03',
#  'P05',
#  'K02',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'M01',
#  'K00',
#  'M05',
#  'K00',
#  'P05',
#  'P05',
#  'K00',
#  'P05',
#  'M05',
#  'P05',
#  'K00',
#  'K00',
#  'M03',
#  'M05',
#  'M05',
#  'P05',
#  'P01',
#  'M05',
#  'M02',
#  'K00',
#  'M01',
#  'M05',
#  'K00',
#  'M01',
#  'K02',
#  'M01',
#  'K01',
#  'M02',
#  'P01',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'K00',
#  'K01',
#  'M01',
#  'K00',
#  'M05',
#  'M05',
#  'M05',
#  'K01',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'K00',
#  'K01',
#  'K00',
#  'P05',
#  'M05',
#  'P03',
#  'M03',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P03',
#  'P05',
#  'M03',
#  'P05',
#  'P03',
#  'K02',
#  'P01',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M03',
#  'M05',
#  'P05',
#  'M01',
#  'K01',
#  'M05',
#  'M01',
#  'M05',
#  'P04',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'K00',
#  'M02',
#  'M05',
#  'P01',
#  'M01',
#  'M05',
#  'P05',
#  'M05',
#  'K01',
#  'K01',
#  'M01',
#  'M05',
#  'K00',
#  'M05',
#  'M05',
#  'M05',
#  'M04',
#  'P03',
#  'P03',
#  'K00',
#  'K01',
#  'M05',
#  'P01',
#  'P05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'P03',
#  'M05',
#  'M05',
#  'K01',
#  'P05',
#  'M03',
#  'M05',
#  'P05',
#  'M05',
#  'P01',
#  'M05',
#  'M01',
#  'P05',
#  'M05',
#  'P05',
#  'P05',
#  'K00',
#  'M05',
#  'M05',
#  'M05',
#  'M05',
#  'P01',
#  'P05',
#  'P05',
#  'M05',
#  'P01',
#  'M05',
#  'P05',
#  'K00',
#  'P05',
#  'K01',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'P05',
#  'M00',
#  'M05',
#  'M05',
#  'M05',
#  'M03',
#  'P03',
#  'M03',
#  'M05',
#  'K00',
#  'M05',
#  'M01',
#  'K00',
#  'P03',
#  'P05',
#  'M05',
#  'K00',
#  'M01',
#  'M05',
#  'M05',
#  'K00',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P05',
#  'P05',
#  'M03',
#  'K00',
#  'M01',
#  'M05',
#  'M05',
#  'M05',
#  'P03',
#  'M05',
#  'M05',
#  'P01',
#  'M05',
#  'P03',
#  'M05',
#  'M01',
#  'P05',
#  'K01',
#  'M04',
#  'P05',
#  'P01',
#  'M03',
#  'M05',
#  'M05',
#  'K00',
#  'P03',
#  'M05',
#  'P03',
#  'M05',
#  'P01',
#  'P05',
#  'M01',
#  'M05',
#  'P05',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'P00',
#  'M03',
#  'M05',
#  'M05',
#  'P03',
#  'P05',
#  'M05',
#  'M05',
#  'K00',
#  'P05',
#  'M05',
#  'P05',
#  'M05',
#  'M05',
#  'P05',
#  'K00',
#  'P01',
#  'P05',
#  'M05',
#  'M01',
#  'M05',
#  'K00',
#  'P05',
#  'M05',
#  'M05',
#  'M05',
#  'M01',
#  'M05',
#  'M05',
#  'P05',
#  'K02',
#  'M05',
#  'M05',
#  'M05',
#  'P05',
#  'M05',
#  'K01',
#  'P05',
#  'M05',
#  'P05',
#  'P05',
#  'P05',
#  'M03',
#  'P03',
#  'M04',
#  'M03',
#  'M05',
#  'P05',
#  'M03',
#  'M05',
#  'M05',
#  'P03',
#  'P05',
#  'M03',
#  'M03',
#  'M01',
#  'M03',
#  'K00',
#  'P05',
#  'M03',
#  'M05',
#  'K00',
#  'K00',
#  'M05',
#  'K00',
#  'P05',
#  'P05',
#  'K00',
#  'P03',
#  'K00',
#  'P01',
#  'P05',
#  'M03',
#  'M03',
#  'P05',
#  'M05',
#  'M03',
#  'K00',
#  'K00',
#  'M03',
#  'M05',
#  'M05',
#  'M05',
#  'K02',
#  'P01',
#  'M03',
#  'P05',
#  'P00',
#  ...]
